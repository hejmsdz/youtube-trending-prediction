# %%
import os
from googleapiclient.discovery import build as build_api_client

assert 'YOUTUBE_API_KEY' in os.environ
yt = build_api_client('youtube', 'v3', developerKey=os.environ['YOUTUBE_API_KEY'])

# %%
def yt_search(region, max_results):
    service = yt.search()
    request = service.list(
        part='snippet',
        publishedAfter='2017-11-15T00:00:00Z',
        publishedBefore='2018-06-16T00:00:00Z',
        regionCode=region,
        type='video',
        maxResults=25
    )
    results_so_far = 0
    while request:
        response = request.execute()
        yield response['items']
        
        results_so_far += len(response['items'])
        if results_so_far >= max_results:
            break
        request = service.list_next(request, response)

# %%
# test
i = 0
for page in yt_search(region='PL', max_results=100):
    for video in page:
        print(i, video['id']['videoId'], video['snippet']['title'])
        i += 1
# Out:
# 0 XtB0LqyJsdA Michael Bublé - Cold December Night [Official HD]
# 1 pw3PhhSfcQg Michael Bublé - All I Want For Christmas Is You [Official HD]
# 2 SK7cpuhwoP0 Michael Bublé - Mis Deseos / Feliz Navidad (ft. Thalia) [Official HD Audio]
# 3 8TBDBCdaf3Y 장우영 (Of 2PM) &quot;Going Going&quot; M/V
# 4 BURBlSYPmBU The Greatest Showman Cast - Come Alive (Official Audio)
# 5 0yhI35F2NB0 Michael Bublé - I&#39;ll Be Home For Christmas [Official HD]
# 6 IcC1Bp13n_4 Who You Say I Am Lyric Video - Hillsong Worship
# 7 ZxLc6P2Ii5Q AJR - Come Hang Out (Official Music Video)
# 8 pd7AMDMotyM Ozuna X Ele A El Dominio  - Balenciaga (Video Oficial)
# 9 TAoMWdTYqRE DVD PRAZER, EU SOU FERRUGEM: &quot;SINTO SUA FALTA&quot;
# 10 JnOLam2AwXY Michael Bublé - Santa Baby [Official HD]
# 11 XM0hh8OFO4M Rilès - SHOULD I (Music Video)
# 12 ZYFzPkANmXk Quien Dices Que Soy - Hillsong en Español
# 13 akdkEh-fzes The Greatest Showman Cast - A Million Dreams (Reprise) [Official Audio]
# ...
