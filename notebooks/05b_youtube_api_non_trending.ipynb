# %%
import os
import numpy as np
import pandas as pd
import requests
import tqdm.notebook
import json
from googleapiclient.discovery import build as build_api_client
from loaders import load_semi_supervised, load_categories, load_all_videos, load_csv, load_thumbnails

# %%
key = 'API_KEY_HERE'

# %%
def search_relevant_videos(region_code, video_id):
    relevant_videos_ids = list()
    payload = {
      'publishedAfter': '2017-11-15T00:00:00Z',
      'publishedBefore': '2018-06-16T00:00:00Z',
      'order': 'relevance',
      'part': 'id',
      'maxResults': 50,
      'regionCode': region_code,
      'type': 'video',
      'relatedToVideoId': video_id,
      'key': key
    }

    response = requests.get('https://www.googleapis.com/youtube/v3/search', params=payload)
    if response.status_code == 200:
        content = response.json()
        items = content['items']

        for item in items:
            relevant_videos_ids.append(item['id']['videoId'])
            
    elif response.status_code == 404:
        return relevant_videos_ids
    
    else:
        raise Exception(response.status_code)

    return relevant_videos_ids

# %%
def get_videos_data(video_ids):
    output = dict()
    payload = {
      'part': 'id,snippet,statistics',
      'id': ','.join(video_ids),
      'key': key
    }

    response = requests.get('https://www.googleapis.com/youtube/v3/videos', params=payload)
    if response.status_code == 200:
        content = response.json()
        items = content['items']

        for item in items:
            output[item['id']] = item
            
    elif response.status_code == 404:
        return output
    
    else:
        raise Exception(response.status_code)

    return output

# %%
non_trending = pd.DataFrame(columns=['video_id', 'relevant_to', 'title', 'channel_title', 'category_id', 'publish_time', 'tags', 'views', 'likes', 'dislikes', 'comment_count', 'thumbnail_link', 'description', 'image_url'])

# %%
def filter_trending(videos_ids):
  return [vId for vId in videos_ids if vId not in trending_videos_ids]

# %%
def load_into_non_trending_df(relevant_to, content_dict, non_trending):
  for item in content_dict.values():
    video_id = item['id']

    snippet = item['snippet']
    title = snippet.get('title', '')
    channel_title = snippet.get('channelTitle', '')
    category_id = int(snippet.get('categoryId', '0'))
    publish_time = pd.to_datetime(snippet['publishedAt'], format='%Y-%m-%dT%H:%M:%S')
    tags = snippet.get('tags', [])
    thumbnail_link = snippet['thumbnails']['default']['url']
    description = snippet.get('description', '')
    
    for size in ['standard', 'high', 'medium', 'default']:
      if size in snippet['thumbnails']:
        image_url = snippet['thumbnails'][size]['url']
        break

    statistics = item['statistics']
    views = statistics.get('viewCount', -1)
    likes = statistics.get('likeCount', -1)
    dislikes = statistics.get('dislikeCount', -1)
    comment_count = statistics.get('commentCount', -1)

    serie = pd.Series([video_id, relevant_to, title, channel_title, category_id, publish_time, tags, views, likes, dislikes, comment_count, thumbnail_link, description, image_url], index=non_trending.columns)
    non_trending = non_trending.append(serie, ignore_index=True)
  return non_trending

# %%
def load_videos(relevant):
    videos_data_dict = dict()
    for video_ids in np.array_split(filter_trending(relevant), 3):
        videos_data_dict.update(get_videos_data(video_ids))
  
    return videos_data_dict

# %%
processed_df = load_all_videos()
trending_videos_ids = set(processed_df['video_id'])

with open('../youtube_data/loaded_relevant_videos_ids.json') as f:
    loaded_videos = json.load(f)

non_trending = pd.read_csv('../youtube_data/non_trending.csv', header=0)

try:
    for relevant_to in trending_videos_ids:
      if relevant_to not in loaded_videos:
        relevant_videos_ids = search_relevant_videos('US', relevant_to)
        relevant_videos_ids = filter_trending(relevant_videos_ids)
        print('------------------------ ----------------------')
        print(relevant_to)
        print(relevant_videos_ids)
        if len(relevant_videos_ids) > 0:
          content = load_videos(relevant_videos_ids)
          non_trending = load_into_non_trending_df(relevant_to, content, non_trending)
          non_trending.to_csv('../youtube_data/non_trending.csv', index=False)
          loaded_videos.append(relevant_to)
except Exception as e:
    print('ERROR:')
    print(e)
finally:
    with open('../youtube_data/loaded_relevant_videos_ids.json', 'w') as f:
        json.dump(loaded_videos, f)
# Out:
# ------------------------ ----------------------
# NBkC83-vh9A
# []
# ------------------------ ----------------------
# gvuvxLzUB-w
# []
# ------------------------ ----------------------
# 76XBys_HXq4
# []
# ------------------------ ----------------------
# 4MtAl7F6xio
# []
# ------------------------ ----------------------
# abSc5wLOqBM
# []
# ------------------------ ----------------------
# J3IbiFCR-Xs
# []
# ------------------------ ----------------------
# aAm6AHr14zY
# []
# ------------------------ ----------------------
# VoUEz9yQJ8w
# []
# ------------------------ ----------------------
# JVapiOu7Hkc
# []
# ------------------------ ----------------------
# g7IfZX91qV0
# []
# ------------------------ ----------------------
# erybgSeUHus
# []
# ------------------------ ----------------------
# 2omJBSQcm5g
# []
# ------------------------ ----------------------
# IE5TzELzvmU
# []
# ------------------------ ----------------------
# QaASZecxQww
# []
# ------------------------ ----------------------
# WF82ABLw8s4
# []
# ------------------------ ----------------------
# Lx_rI8ACqsc
# []
# ------------------------ ----------------------
# 0XtCnGT0B20
# []
# ------------------------ ----------------------
# dBTKW8NKAt4
# []
# ------------------------ ----------------------
# xkYpO9ATUT0
# []
# ------------------------ ----------------------
# OPi9nTE70aA
# []
# ------------------------ ----------------------
# xa2LxGIQ1DQ
# []
# ------------------------ ----------------------
# AEAHRq62p3Q
# []
# ------------------------ ----------------------
# BLOIU9DpLq4
# []
# ------------------------ ----------------------
# hRAGY4BaFQs
# []
# ------------------------ ----------------------
# xLvkFer6aOY
# []
# ------------------------ ----------------------
# tpcJt1HF6y8
# []
# ------------------------ ----------------------
# NqH0kLCm1cI
# []
# ------------------------ ----------------------
# 72Qahj0U0Lw
# []
# ------------------------ ----------------------
# JWa_Lbdl0J0
# []
# ------------------------ ----------------------
# d6u1muHTO5A
# []
# ------------------------ ----------------------
# YrzxVhbDc-4
# []
# ------------------------ ----------------------
# ccgIXa7TIkc
# []
# ------------------------ ----------------------
# 7LNTrcguDaw
# []
# ------------------------ ----------------------
# OQ8v_KUS0Qg
# []
# ------------------------ ----------------------
# c_y2xNUu2aU
# []
# ------------------------ ----------------------
# CxGUmtRLm5g
# []
# ------------------------ ----------------------
# 7dKownfx75E
# []
# ------------------------ ----------------------
# HBS9783c0BI
# []
# ------------------------ ----------------------
# 5WUDfviiKRE
# []
# ------------------------ ----------------------
# tH2U9_v7q9E
# []
# ------------------------ ----------------------
# 0YVbVXOjJv4
# []
# ------------------------ ----------------------
# NeH_wFJ8lZc
# []
# ------------------------ ----------------------
# R_O5x0LNksM
# []
# ------------------------ ----------------------
# Zn99TMv0vac
# []
# ------------------------ ----------------------
# 3ekEfYNQJ1s
# []
# ------------------------ ----------------------
# pfX353Wc0GA
# []
# ------------------------ ----------------------
# 1Wo6WEBhBBw
# []
# ------------------------ ----------------------
# QqJZxmU-iZM
# []
# ------------------------ ----------------------
# 6mDsa-AqNcQ
# []
# ------------------------ ----------------------
# 1Nu_oGucpDI
# []
# ------------------------ ----------------------
# d6YkGejS6IM
# []
# ------------------------ ----------------------
# _Iz83-Cmt6A
# []
# ------------------------ ----------------------
# rRhzbPW3gzw
# []
# ------------------------ ----------------------
# PuaBdAwbbZY
# []
# ------------------------ ----------------------
# oCXvPWJClJg
# []
# ------------------------ ----------------------
# Cyf1eXYE9Bw
# []
# ------------------------ ----------------------
# h0xHxZpNAHw
# []
# ------------------------ ----------------------
# qYNNT1WIhwM
# []
# ------------------------ ----------------------
# 5nEogChRGE8
# []
# ------------------------ ----------------------
# SWcdQ-6TKmI
# []
# ------------------------ ----------------------
# R-lhShtMfvQ
# []
# ------------------------ ----------------------
# alRtHXnZMOI
# []
# ------------------------ ----------------------
# JvVYL7s-HMc
# []
# ------------------------ ----------------------
# 4eKYR_iL5eU
# []
# ------------------------ ----------------------
# sosxR6ZALjc
# []
# ------------------------ ----------------------
# oJ_g5fUxtQo
# []
# ------------------------ ----------------------
# 4FBqT80fVKY
# []
# ------------------------ ----------------------
# OO5_E0_NAOg
# []
# ------------------------ ----------------------
# bJje-B9YLIU
# []
# ------------------------ ----------------------
# DfYRIN3U3SU
# []
# ------------------------ ----------------------
# KMTJrFPie6w
# []
# ------------------------ ----------------------
# WI06POju7UQ
# []
# ------------------------ ----------------------
# y8dm1IbpMj4
# []
# ------------------------ ----------------------
# gRhgPUbOIyA
# []
# ------------------------ ----------------------
# RdyeDDJLTAM
# []
# ------------------------ ----------------------
# 9OGr-2g0zVs
# []
# ------------------------ ----------------------
# tjVJgR4OrgM
# []
# ------------------------ ----------------------
# t9QxlDaI3Y4
# []
# ------------------------ ----------------------
# WlN04DM8ol0
# []
# ------------------------ ----------------------
# sNTLwCEiIJ4
# []
# ------------------------ ----------------------
# Wiq7z_HS5DY
# []
# ------------------------ ----------------------
# aTYkKrhj5pE
# []
# ------------------------ ----------------------
# 1lPvUKtHBJA
# []
# ------------------------ ----------------------
# YDyqnYhxTTw
# []
# ------------------------ ----------------------
# E7zFj4iUn0U
# []
# ------------------------ ----------------------
# QNzzJzdgUto
# []
# ------------------------ ----------------------
# _J7dEhYttbQ
# []
# ------------------------ ----------------------
# hSvnepZS26s
# []
# ------------------------ ----------------------
# nUv22OHdjQU
# []
# ------------------------ ----------------------
# 7xN52zQzYy8
# ['_yWmDz1cTfw', 'e8jMthH5oRQ', 'xdtbAX1-ZO0', '8EpdR2nHK3k', 'ZnsUZkauDnM', 'BHvPQu2QczM', 'If0cBFokr00', 'IHFxRa3GAZE', 'sJsq5uP7IjI', 'JGZgiJ78RC4', '2YvO0tF065k', 'pvLIKrHVZx8', '2oGZB9tZ2Vw', '6XzU4h88s1Q', 'ZrBqYweKNF8', 'JqkV_UHYNi0', 'bgjI7ygXTF8', '3w8stfnkEiQ', 'hBB8Uq74Zqo', 'DOZS4YwqNMU', 'sb632ngp6n4', 'WHJvhcqNSqw', 'DsVuqgF2R6w', 'aGd6rDs5jsg', '6lgz3ftDI9I', 'EmnRaI_pVbI', 'Ye9JMb38StM', 'o8-ergMTsUA', '8S
# ------------------------ ----------------------
# FtX7GY_iPok
# []
# ERROR:
# 403

# %%
print(len(non_trending))
non_trending.head()
# Out:
# 8798
#       video_id  relevant_to  \
# 0  JKmXamRF9wM  817P8W8-mGE
# 1  lp-EO5I60KA  817P8W8-mGE
# 2  bIB8EWqCPrQ  817P8W8-mGE
# 3  1BR3ycghvTU  jCVkaZChKmc
# 4  NCJUpiLA8Y0  jCVkaZChKmc
#
#                                                title  channel_title  \
# 0     Ed Sheeran ‒ Perfect Duet (Lyrics) ft. Beyoncé  SyrebralVibes
# 1    Ed Sheeran - Thinking Out Loud [Official Video]     Ed Sheeran
# 2  Ed Sheeran - Supermarket Flowers [Official Audio]     Ed Sheeran
# 3  WET N WILD Photo Focus Foundation Review & Wea...   Casey Holmes
# 4  DRUGSTORE First Impression 😍💦 Wet n Wild Found...       Shaaanxo
#
#    category_id               publish_time  \
# 0           10  2017-12-01 04:04:01+00:00
# 1           10  2014-10-07 13:57:37+00:00
# 2           10  2017-03-03 07:11:55+00:00
# 3           26  2017-01-18 02:47:23+00:00
# 4           26  2018-01-16 20:14:25+00:00
#
#                                                 tags       views     likes  \
# 0  ['syrebralvibes', 'syrebral vibes', 'electroni...     5434852     40379
# 1  ['edsheeran', 'ed sheeran', 'acoustic', 'live'...  3014436913  11361560
# 2  ['edsheeran', 'ed sheeran', 'acoustic', 'live'...   127235566    651588
# 3  ['wet n wild', 'drugstore makeup', 'wear test'...     1456075     30469
# 4  ['first impression', 'wet n wild photo focus',...      256849     11272
#
#   dislikes comment_count                                  thumbnail_link  \
# 0     2014          1347  https://i.ytimg.com/vi/JKmXamRF9wM/default.jpg
# 1   499596        315492  https://i.ytimg.com/vi/lp-EO5I60KA/default.jpg
# 2    17037         26463  https://i.ytimg.com/vi/bIB8EWqCPrQ/default.jpg
# 3      684          2151  https://i.ytimg.com/vi/1BR3ycghvTU/default.jpg
# 4      110           953  https://i.ytimg.com/vi/NCJUpiLA8Y0/default.jpg
#
#                                          description  \
# 0  » Download Ed Sheeran ‒ Perfect Duet (Lyrics) ...
# 1  Tickets for the Divide tour here - http://www....
# 2  ÷. Out Now: https://atlanti.cr/yt-album\n\nSub...
# 3  Don't forget to subscribe here-- http://bit.ly...
# 4  Today I'm testing the Wet n Wild Photo Focus F...
#
#                                           image_url
# 0  https://i.ytimg.com/vi/JKmXamRF9wM/sddefault.jpg
# 1  https://i.ytimg.com/vi/lp-EO5I60KA/sddefault.jpg
# 2  https://i.ytimg.com/vi/bIB8EWqCPrQ/sddefault.jpg
# 3  https://i.ytimg.com/vi/1BR3ycghvTU/sddefault.jpg
# 4  https://i.ytimg.com/vi/NCJUpiLA8Y0/sddefault.jpg

# %%
load_thumbnails(non_trending)
# Out:
# 100%|██████████| 8600/8600 [05:47<00:00, 24.75it/s]
# Downloaded: 8600
# Broken links: 0
# Already present: 0
# Skipped: 0
